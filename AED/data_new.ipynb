# %%
import pandas as pd 
import os

# %%
df = pd.read_csv("../Dataset/data_merged.csv")

# %%
df.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
#        'instrumentalness', 'liveness', 'loudness', 'popularity', 'speechiness',
#        'tempo', 'valence', 'year', 'key_0', 'key_1', 'key_2', 'key_3', 'key_4',
#        'key_5', 'key_6', 'key_7', 'key_8', 'key_9', 'key_10', 'key_11',
#        'minor', 'major', 'acousticness_ar', 'danceability_ar',
#        'duration_ms_ar', 'energy_ar', 'instrumentalness_ar', 'liveness_ar',
#        'loudness_ar', 'speechiness_ar', 'tempo_ar', 'valence_ar',
#        'popularity_ar', 'count', 'key_0_ar', 'key_1_ar', 'key_2_ar',
#        'key_3_ar', 'key_4_ar', 'key_5_ar', 'key_6_ar', 'key_7_ar', 'key_8_ar',
#        'key_9_ar', 'key_10_ar', 'key_11_ar', 'minor_ar', 'major_ar',
#        'acousticness_yr', 'danceability_yr', 'duration_ms_yr', 'energy_yr',
#        'instrumentalness_yr', 'liveness_yr', 'loudness_yr', 'speechiness_yr',
#        'tempo_yr', 'valence_yr', 'popularity_yr', 'mode', 'key_0_yr',
# ...

# %%
df.shape
# Out:
# (172230, 72)

# %%
df_ar = pd.read_csv("../Dataset/data_by_artist.csv")

# %%
df_ar.head()
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.467143  270436.142857  0.488286          0.009400  0.195000
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count
# ...

# %%
df_ar.shape
# Out:
# (32539, 15)

# %%
df_ar.columns
# Out:
# Index(['artists', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode', 'count'],
#       dtype='object')

# %%
df_yr = pd.read_csv("../Dataset/data_by_year.csv")

# %%
df_yr.head()
# Out:
#    year  acousticness  danceability    duration_ms    energy  \
# 0  1920      0.631242      0.515750  238092.997135  0.418700
# 1  1921      0.862105      0.432171  257891.762821  0.241136
# 2  1922      0.828934      0.575620  140135.140496  0.226173
# 3  1923      0.957247      0.577341  177942.362162  0.262406
# 4  1924      0.940200      0.549894  191046.707627  0.344347
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.354219  0.216049 -12.654020     0.082984  113.226900  0.498210
# 1          0.337158  0.205219 -16.811660     0.078952  102.425397  0.378276
# 2          0.254776  0.256662 -20.840083     0.464368  100.033149  0.571190
# 3          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 4          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
#
#    popularity  key  mode
# 0    0.610315    2     1
# 1    0.391026    2     1
# 2    0.090909    5     1
# 3    5.205405    0     1
# ...

# %%
df_yr.shape
# Out:
# (102, 14)

# %%
df_yr.columns
# Out:
# Index(['year', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode'],
#       dtype='object')

# %%
df_w_g = pd.read_csv("../Dataset/data_w_genres.csv")

# %%
df_w_g
# Out:
#                                                  artists  acousticness  \
# 0                       "Cats" 1981 Original London Cast      0.598500
# 1                              "Cats" 1983 Broadway Cast      0.862538
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# ...                                                  ...           ...
# 32534                                                김효근      0.939000
# 32535                                                 나율      0.717000
# 32536                                                미스티      0.416000
# 32537                  시온 Zion & 한해 Hanhae of 팬텀 Phantom      0.288000
# 32538                                                조정현      0.568000
#
#        danceability    duration_ms    energy  instrumentalness  liveness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172230 entries, 0 to 172229
# Data columns (total 72 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   acousticness         172230 non-null  float64
#  1   danceability         172230 non-null  float64
#  2   duration_ms          172230 non-null  int64
#  3   energy               172230 non-null  float64
#  4   explicit             172230 non-null  int64
#  5   instrumentalness     172230 non-null  float64
#  6   liveness             172230 non-null  float64
#  7   loudness             172230 non-null  float64
#  8   popularity           172230 non-null  int64
#  9   speechiness          172230 non-null  float64
#  10  tempo                172230 non-null  float64
#  11  valence              172230 non-null  float64
#  12  year                 172230 non-null  int64
#  13  key_0                172230 non-null  int64
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 0           0.013100        0.2560       182347   0.895         0
# 1           0.980000        0.2770       206972   0.145         0
# 2           0.795000        0.6850       314667   0.483         0
# 3           0.656000        0.7880       179747   0.808         0
# 4           0.302000        0.0753       498560   0.150         0
# ...              ...           ...          ...     ...       ...
# 172225      0.000067        0.5670        37000   0.862         0
# 172226      0.000994        0.3960       501824   0.979         0
# 172227      0.864000        0.6380       161560   0.156         0
# 172228      0.029900        0.5330       342827   0.547         0
# 172229      0.141000        0.5260       139514   0.432         0
#
#         instrumentalness  liveness  loudness  popularity  speechiness  ...  \
# 0               0.000106    0.0821    -4.860          29       0.0707  ...
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

y = df['popularity']
X = df.drop(columns=['popularity'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
param = {'n_estimators':[100,300,500],'max_depth':[5,8,10]}
rf = RandomForestRegressor()
g = GridSearchCV(rf,param_grid=param,cv=5,scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)

# %%
g.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ......................max_depth=5, n_estimators=100; total time= 3.6min
# [CV] END ......................max_depth=5, n_estimators=100; total time= 3.6min
# [CV] END ......................max_depth=5, n_estimators=100; total time= 3.6min
# [CV] END ......................max_depth=5, n_estimators=100; total time= 3.6min
# [CV] END ......................max_depth=5, n_estimators=100; total time= 3.6min
# [CV] END ......................max_depth=5, n_estimators=300; total time=12.1min
# [CV] END ......................max_depth=5, n_estimators=300; total time=12.1min
# [CV] END ......................max_depth=5, n_estimators=300; total time=12.2min
# [CV] END ......................max_depth=5, n_estimators=300; total time=12.9min
# [CV] END ......................max_depth=5, n_estimators=300; total time=12.9min
# [CV] END ......................max_depth=8, n_estimators=100; total time= 6.8min
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
def plot_residuals(y_true, y_pred):
    residuals = y_true - y_pred
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    sns.scatterplot(x=y_pred, y=residuals)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.xlabel('Predicted Values')
    plt.ylabel('Residuals')
    
    plt.subplot(1, 2, 2)
    sns.histplot(residuals, kde=True)
    plt.xlabel('Residuals')
    
    plt.tight_layout()
    plt.show()


def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    return {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'R²': r2
    }
results=[]
model_rf = g.best_estimator_
y_pred_test = model_rf.predict(X_test)
results.append(evaluate_model(y_test, y_pred_test))
plot_residuals(y_test, y_pred_test)
plt.plot(y_pred_test,y_test,".")
plt.show()
evaluate_model(y_test, y_pred_test)
# Out:
# {'MSE': 63.629068489976724,
#  'RMSE': np.float64(7.976783091571233),
#  'MAE': 5.076278039178318,
#  'R²': 0.8663008025037808}

# %%
gr = GradientBoostingRegressor()
params1 =  {
           'n_estimators': [50, 100, 200],
            'learning_rate': [0.01, 0.1, 0.2],
        }
g1 = GridSearchCV(gr,param_grid=params1,cv=5,scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)

# %%
g1.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ................learning_rate=0.01, n_estimators=50; total time= 2.0min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time= 2.0min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time= 2.0min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time= 2.0min
# [CV] END ................learning_rate=0.01, n_estimators=50; total time= 2.0min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 3.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 3.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 3.8min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 3.4min
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time= 3.4min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time= 1.6min
# ...

# %%
model_rf1 = g1.best_estimator_
y_pred_test1 = model_rf1.predict(X_test)
results.append(evaluate_model(y_test, y_pred_test1))
plot_residuals(y_test, y_pred_test1)
plt.plot(y_pred_test1,y_test,".")
plt.show()
evaluate_model(y_test, y_pred_test1)
# Out:
# {'MSE': 67.6301226924737,
#  'RMSE': np.float64(8.223753564673112),
#  'MAE': 5.415617937012697,
#  'R²': 0.8578936743042381}

# %%
from xgboost import XGBRegressor
m =  XGBRegressor()
params2 = {
            'n_estimators': [50, 100, 200,500],
            'max_depth': [3, 6, 9],
             'subsample': [0.8, 1.0],
            'colsample_bytree': [0.8, 1.0]
        }

g2 = GridSearchCV(m,param_grid=params2,cv=5,scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)

# %%
g2.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.7s
# ...

# %%
model_rf2 = g2.best_estimator_
y_pred_test2 = model_rf2.predict(X_test)
results.append(evaluate_model(y_test, y_pred_test2))
plot_residuals(y_test, y_pred_test2)
plt.plot(y_pred_test2,y_test,".")
plt.show()
evaluate_model(y_test, y_pred_test2)
# Out:
# {'MSE': 62.352420806884766,
#  'RMSE': np.float64(7.896354906340315),
#  'MAE': 5.075111389160156,
#  'R²': 0.8689833283424377}

# %%
results
# Out:
# [{'MSE': 63.629068489976724,
#   'RMSE': np.float64(7.976783091571233),
#   'MAE': 5.076278039178318,
#   'R²': 0.8663008025037808},
#  {'MSE': 67.6301226924737,
#   'RMSE': np.float64(8.223753564673112),
#   'MAE': 5.415617937012697,
#   'R²': 0.8578936743042381},
#  {'MSE': 62.352420806884766,
#   'RMSE': np.float64(7.896354906340315),
#   'MAE': 5.075111389160156,
#   'R²': 0.8689833283424377}]
