# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsOneClassifier
import xgboost 

from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score, 
)

plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv('Copia de data_merged.csv')

# %%
df_processed = df.copy()

initial_rows = len(df_processed)
df_processed = df_processed.dropna()

df_processed['duration_ms'] = df_processed['duration_ms']/60000

def categorize_popularity(popularity):
    if popularity == 0:
        return 0 #no popular
    elif popularity<=20:
        return 1 # baja
    elif popularity <=40:
        return 2 # media
    return 3 # alta

df_processed['popularity_multiclass'] = df_processed['popularity'].apply(categorize_popularity)
print("\nVariable multiclase 3 niveles (popularity_multiclass):")
multiclass_counts = df_processed['popularity_multiclass'].value_counts().sort_index()
multiclass_labels = ['no popular','Baja', 'Media', 'Alta']
for i, (count, label) in enumerate(zip(multiclass_counts, multiclass_labels)):
    print(f"   {i} ({label}): {count} ({count/len(df_processed)*100:.1f}%)")
# Out:
# Variable multiclase 3 niveles (popularity_multiclass):
#    0 (no popular): 39729 (23.1%)
#    1 (Baja): 34033 (19.8%)
#    2 (Media): 51035 (29.6%)
#    3 (Alta): 47433 (27.5%)

# %%
df_processed['popularity_multiclass'].value_counts().plot(kind='bar')
plt.savefig("4clases.png",dpi=421)

# %%
_X = df_processed.copy()

X = _X.drop(columns=['popularity','popularity_multiclass'])
y_multiclass_3 = df_processed['popularity_multiclass']

# %%
df_processed.groupby('popularity_multiclass')['popularity'].describe()
# Out:
#                          count       mean       std   min   25%   50%   75%  \
# popularity_multiclass
# 0                      39729.0   0.000000  0.000000   0.0   0.0   0.0   0.0
# 1                      34033.0   9.619575  6.125172   1.0   4.0   9.0  15.0
# 2                      51035.0  30.747330  5.652618  21.0  26.0  31.0  36.0
# 3                      47433.0  54.153163  9.966513  41.0  46.0  52.0  61.0
#
#                          max
# popularity_multiclass
# 0                        0.0
# 1                       20.0
# 2                       40.0
# 3                      100.0

# %%
selector = SelectKBest(score_func=f_classif,k='all')
X_new = selector.fit_transform(X,y_multiclass_3)
total_score = selector.scores_
sorted_scoress = np.sort(total_score)[::-1]
plt.figure(figsize=(10,8))
plt.plot(range(1,X.shape[1]+1),sorted_scoress,'bo-')

# %%
selector = SelectKBest(score_func=f_classif,k=6)
X_new = selector.fit_transform(X,y_multiclass_3)
select = selector.get_feature_names_out()
select
# Out:
# array(['popularity_ar', 'acousticness_yr', 'energy_yr',
#        'instrumentalness_yr', 'tempo_yr', 'popularity_yr'], dtype=object)

# %%
_X=X[select]
y =y_multiclass_3

# %%
scaler1 = StandardScaler()

X_train_reduce, X_test_reduce, y_train_reduce, y_test_reduce = train_test_split(
    _X, y, 
    test_size=0.2, 
    stratify=y,
    random_state=42
)

# %%
X_train_reduce = scaler1.fit_transform(X_train_reduce)
X_test_scaled = scaler1.transform(X_test_reduce)

# %%
from sklearn.ensemble import ExtraTreesClassifier,HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
models = {
    'RandomForest': RandomForestClassifier(class_weight='balanced'),
    'HistoradientBoosting': HistGradientBoostingClassifier(),
    'XGBoost': xgboost.XGBClassifier(objective='multi:softmax',num_class=4),
    'ExtraTrees': ExtraTreesClassifier(class_weight='balanced'),
    'DecisionTree': DecisionTreeClassifier(class_weight='balanced'),
    'LogisticRegression':LogisticRegression(class_weight='balanced'),
    "KNN":KNeighborsClassifier()
}
param_grids = {
    'LogisticRegression':{
    'C':[0.001,0.1,10],
    'max_iter':[100,200,500],
    
    },
    'KNN':{
        'n_neighbors':[3,4,7,9],
        'algorithm':['ball_tree','auto','kd_tree','brute'],
        'p':[1,2]
    },
    'RandomForest': {
        'n_estimators': [100, 300, 500],
        'max_depth': [None, 10, 20]
    },
    'XGBoost': {
        'n_estimators': [100, 300, 500],
        'max_depth': [3, 10, 20]
    },
    'ExtraTrees': {
        'n_estimators': [100, 300, 500],
        'max_depth': [None, 10, 20]
    },
    'DecisionTree': {
        'max_depth': [None, 10, 20]
    },
    'HistoradientBoosting':{
        'max_iter':[100,200,300],
        'max_depth':[3,5],

    }
}
results = {}

for name, model in models.items():
    p=param_grids[name]
    new_p = {f"estimator__{x}":y for x,y in p.items()}
    grid = GridSearchCV(OneVsOneClassifier(model),new_p , cv=5, scoring='f1_macro', n_jobs=-1,verbose=2)
    grid.fit(X_train_reduce, y_train_reduce)
    best = grid.best_estimator_
    y_pred = best.predict(X_test_scaled)
    r = classification_report(y_test_reduce, y_pred)
    print(f"\n{name}")
    print(f"Best params: {grid.best_params_}")
    print(r)
    cm = confusion_matrix(y_test_reduce, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['No Popular', 'bajo','media','alta'],
                yticklabels=['No Popular', 'bajo','media','alta'])
    plt.title(f'{name} - Confusion Matrix')
    plt.ylabel('Valor Real')
    plt.xlabel('Predicción')
    plt.show()
    print("train")
    y_pred = best.predict(X_train_reduce)
    r = classification_report(y_train_reduce, y_pred)
    print(f"\n{name}")
    print(f"Best params: {grid.best_params_}")
    print(r)
    cm = confusion_matrix(y_train_reduce, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['No Popular', 'bajo','media','alta'],
                yticklabels=['No Popular', 'bajo','media','alta'])
    plt.title(f'{name} - Confusion Matrix')
    plt.ylabel('Valor Real')
    plt.xlabel('Predicción')
    plt.show()
    results[name] = grid.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 7.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 7.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 7.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time= 1.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 7.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 7.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time= 1.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time=12.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time=12.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time=12.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 5.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 5.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 5.8min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time=12.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time=12.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 5.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 5.9min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 9.9min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time=10.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time=10.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time=10.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time=10.0min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 7.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 7.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 7.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 7.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 7.0min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=11.1min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=10.6min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=10.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=10.2min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 9.4min
#
# RandomForest
# Best params: {'estimator__max_depth': 20, 'estimator__n_estimators': 300}
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      7946
#            1       0.75      0.82      0.79      6806
#            2       0.72      0.75      0.73     10207
#            3       0.82      0.72      0.76      9487
#
#     accuracy                           0.80     34446
#    macro avg       0.80      0.81      0.80     34446
# weighted avg       0.80      0.80      0.80     34446
# train
#
# RandomForest
# Best params: {'estimator__max_depth': 20, 'estimator__n_estimators': 300}
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     31783
#            1       0.81      0.89      0.85     27227
#            2       0.79      0.82      0.81     40828
#            3       0.90      0.79      0.84     37946
#
#     accuracy                           0.86    137784
#    macro avg       0.86      0.87      0.86    137784
# weighted avg       0.86      0.86      0.86    137784
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ....estimator__max_depth=3, estimator__max_iter=100; total time=  12.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=100; total time=  12.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=100; total time=  12.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=100; total time=  12.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=100; total time=  12.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=200; total time=  22.8s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=200; total time=  23.0s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=200; total time=  24.3s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=200; total time=  22.9s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=200; total time=  22.8s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=300; total time=  24.7s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=100; total time=  17.4s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=300; total time=  29.5s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=300; total time=  29.5s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=300; total time=  28.4s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=100; total time=  15.8s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=100; total time=  16.2s
# [CV] END ....estimator__max_depth=3, estimator__max_iter=300; total time=  30.0s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=100; total time=  15.7s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=100; total time=  15.8s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=200; total time=  25.3s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=200; total time=  25.4s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=200; total time=  25.4s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=200; total time=  25.4s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=200; total time=  25.9s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=300; total time=  28.0s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=300; total time=  28.7s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=300; total time=  26.9s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=300; total time=  21.8s
# [CV] END ....estimator__max_depth=5, estimator__max_iter=300; total time=  22.3s
#
# HistoradientBoosting
# Best params: {'estimator__max_depth': 5, 'estimator__max_iter': 300}
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      7946
#            1       0.74      0.78      0.76      6806
#            2       0.70      0.77      0.74     10207
#            3       0.83      0.70      0.76      9487
#
#     accuracy                           0.79     34446
#    macro avg       0.80      0.79      0.79     34446
# weighted avg       0.79      0.79      0.79     34446
# train
#
# HistoradientBoosting
# Best params: {'estimator__max_depth': 5, 'estimator__max_iter': 300}
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93     31783
#            1       0.75      0.79      0.77     27227
#            2       0.71      0.78      0.74     40828
#            3       0.85      0.71      0.77     37946
#
#     accuracy                           0.80    137784
#    macro avg       0.81      0.80      0.80    137784
# weighted avg       0.80      0.80      0.80    137784
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END estimator__max_depth=3, estimator__n_estimators=100; total time=  17.8s
# [CV] END estimator__max_depth=3, estimator__n_estimators=100; total time=  17.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=100; total time=  17.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=100; total time=  17.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=100; total time=  18.0s
# [CV] END estimator__max_depth=3, estimator__n_estimators=300; total time=  51.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=300; total time=  51.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=300; total time=  52.3s
# [CV] END estimator__max_depth=3, estimator__n_estimators=300; total time=  51.9s
# [CV] END estimator__max_depth=3, estimator__n_estimators=300; total time=  52.0s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  31.2s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  31.3s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  31.4s
# [CV] END estimator__max_depth=3, estimator__n_estimators=500; total time= 1.4min
# [CV] END estimator__max_depth=3, estimator__n_estimators=500; total time= 1.4min
# [CV] END estimator__max_depth=3, estimator__n_estimators=500; total time= 1.4min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  31.6s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  32.5s
# [CV] END estimator__max_depth=3, estimator__n_estimators=500; total time= 1.5min
# [CV] END estimator__max_depth=3, estimator__n_estimators=500; total time= 1.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 2.0min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 1.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 1.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 1.4min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 3.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 3.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 3.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time=  51.1s
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time=  51.2s
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 3.2min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 3.1min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 2.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 2.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 2.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 2.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 2.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 4.0min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 4.4min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 4.4min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 4.4min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 4.6min
#
# XGBoost
# Best params: {'estimator__max_depth': 10, 'estimator__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      7946
#            1       0.77      0.78      0.77      6806
#            2       0.71      0.78      0.74     10207
#            3       0.83      0.71      0.76      9487
#
#     accuracy                           0.80     34446
#    macro avg       0.80      0.80      0.80     34446
# weighted avg       0.80      0.80      0.80     34446
# train
#
# XGBoost
# Best params: {'estimator__max_depth': 10, 'estimator__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     31783
#            1       0.80      0.82      0.81     27227
#            2       0.74      0.81      0.77     40828
#            3       0.87      0.74      0.80     37946
#
#     accuracy                           0.83    137784
#    macro avg       0.83      0.83      0.83    137784
# weighted avg       0.83      0.83      0.83    137784
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 1.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 1.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 1.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 4.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 4.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 4.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  41.6s
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 4.1min
# [CV] END estimator__max_depth=None, estimator__n_estimators=300; total time= 4.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  41.5s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  43.0s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  43.7s
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=  40.8s
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time= 6.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time= 6.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time= 6.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 1.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 2.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time= 5.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=500; total time= 5.4min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 2.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=300; total time= 2.2min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.1min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 4.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 5.4min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 5.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.1min
# [CV] END estimator__max_depth=20, estimator__n_estimators=100; total time= 2.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 5.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=500; total time= 7.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 6.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 6.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 6.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 6.6min
# [CV] END estimator__max_depth=20, estimator__n_estimators=300; total time= 6.5min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=10.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time=10.2min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 9.3min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 8.9min
# [CV] END estimator__max_depth=20, estimator__n_estimators=500; total time= 8.5min
#
# ExtraTrees
# Best params: {'estimator__max_depth': 20, 'estimator__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      7946
#            1       0.75      0.82      0.79      6806
#            2       0.72      0.76      0.74     10207
#            3       0.83      0.71      0.77      9487
#
#     accuracy                           0.80     34446
#    macro avg       0.81      0.81      0.81     34446
# weighted avg       0.80      0.80      0.80     34446
# train
#
# ExtraTrees
# Best params: {'estimator__max_depth': 20, 'estimator__n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     31783
#            1       0.81      0.88      0.84     27227
#            2       0.78      0.82      0.80     40828
#            3       0.89      0.77      0.83     37946
#
#     accuracy                           0.85    137784
#    macro avg       0.86      0.86      0.86    137784
# weighted avg       0.85      0.85      0.85    137784
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END ..........................estimator__max_depth=None; total time=   6.0s
# [CV] END ..........................estimator__max_depth=None; total time=   6.1s
# [CV] END ..........................estimator__max_depth=None; total time=   6.1s
# [CV] END ............................estimator__max_depth=10; total time=   4.9s
# [CV] END ............................estimator__max_depth=10; total time=   4.9s
# [CV] END ............................estimator__max_depth=20; total time=   5.7s
# [CV] END ............................estimator__max_depth=10; total time=   4.9s
# [CV] END ............................estimator__max_depth=10; total time=   4.9s
# [CV] END ............................estimator__max_depth=10; total time=   4.9s
# [CV] END ..........................estimator__max_depth=None; total time=   5.7s
# [CV] END ..........................estimator__max_depth=None; total time=   5.9s
# [CV] END ............................estimator__max_depth=20; total time=   5.7s
# [CV] END ............................estimator__max_depth=20; total time=   5.8s
# [CV] END ............................estimator__max_depth=20; total time=   5.6s
# [CV] END ............................estimator__max_depth=20; total time=   4.2s
#
# DecisionTree
# Best params: {'estimator__max_depth': 20}
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      7946
#            1       0.75      0.83      0.78      6806
#            2       0.72      0.73      0.72     10207
#            3       0.80      0.73      0.76      9487
#
#     accuracy                           0.80     34446
#    macro avg       0.80      0.80      0.80     34446
# weighted avg       0.80      0.80      0.79     34446
# train
#
# DecisionTree
# Best params: {'estimator__max_depth': 20}
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     31783
#            1       0.80      0.89      0.84     27227
#            2       0.79      0.80      0.80     40828
#            3       0.88      0.79      0.83     37946
#
#     accuracy                           0.85    137784
#    macro avg       0.86      0.86      0.86    137784
# weighted avg       0.85      0.85      0.85    137784
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ........estimator__C=0.001, estimator__max_iter=100; total time=   1.7s
# [CV] END ........estimator__C=0.001, estimator__max_iter=100; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=100; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=200; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=200; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=200; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=100; total time=   1.8s
# [CV] END ........estimator__C=0.001, estimator__max_iter=100; total time=   1.9s
# [CV] END ........estimator__C=0.001, estimator__max_iter=200; total time=   2.2s
# [CV] END ........estimator__C=0.001, estimator__max_iter=200; total time=   2.2s
# [CV] END ........estimator__C=0.001, estimator__max_iter=500; total time=   2.1s
# [CV] END ........estimator__C=0.001, estimator__max_iter=500; total time=   2.2s
# [CV] END ........estimator__C=0.001, estimator__max_iter=500; total time=   2.1s
# [CV] END ........estimator__C=0.001, estimator__max_iter=500; total time=   2.1s
# [CV] END ........estimator__C=0.001, estimator__max_iter=500; total time=   2.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=100; total time=   3.4s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=100; total time=   3.1s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=100; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=200; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=100; total time=   3.3s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=100; total time=   3.3s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=200; total time=   3.3s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=200; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=200; total time=   3.3s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=200; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=500; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=500; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=500; total time=   3.2s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=500; total time=   3.4s
# [CV] END ..........estimator__C=0.1, estimator__max_iter=500; total time=   3.3s
# [CV] END ...........estimator__C=10, estimator__max_iter=100; total time=   3.5s
# [CV] END ...........estimator__C=10, estimator__max_iter=100; total time=   3.3s
# [CV] END ...........estimator__C=10, estimator__max_iter=100; total time=   3.5s
# [CV] END ...........estimator__C=10, estimator__max_iter=200; total time=   3.5s
# [CV] END ...........estimator__C=10, estimator__max_iter=100; total time=   3.7s
# [CV] END ...........estimator__C=10, estimator__max_iter=100; total time=   3.7s
# [CV] END ...........estimator__C=10, estimator__max_iter=200; total time=   3.7s
# [CV] END ...........estimator__C=10, estimator__max_iter=200; total time=   3.6s
# [CV] END ...........estimator__C=10, estimator__max_iter=200; total time=   3.7s
# [CV] END ...........estimator__C=10, estimator__max_iter=200; total time=   3.5s
# [CV] END ...........estimator__C=10, estimator__max_iter=500; total time=   3.2s
# [CV] END ...........estimator__C=10, estimator__max_iter=500; total time=   3.0s
# [CV] END ...........estimator__C=10, estimator__max_iter=500; total time=   3.1s
# [CV] END ...........estimator__C=10, estimator__max_iter=500; total time=   3.2s
# [CV] END ...........estimator__C=10, estimator__max_iter=500; total time=   3.2s
#
# LogisticRegression
# Best params: {'estimator__C': 0.1, 'estimator__max_iter': 100}
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      7946
#            1       0.64      0.63      0.64      6806
#            2       0.69      0.72      0.70     10207
#            3       0.79      0.72      0.75      9487
#
#     accuracy                           0.74     34446
#    macro avg       0.74      0.74      0.74     34446
# weighted avg       0.74      0.74      0.74     34446
# train
#
# LogisticRegression
# Best params: {'estimator__C': 0.1, 'estimator__max_iter': 100}
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85     31783
#            1       0.64      0.63      0.64     27227
#            2       0.69      0.72      0.70     40828
#            3       0.80      0.72      0.76     37946
#
#     accuracy                           0.74    137784
#    macro avg       0.74      0.74      0.74    137784
# weighted avg       0.74      0.74      0.74    137784
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=1; total time= 4.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=1; total time= 4.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=1; total time= 4.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=1; total time= 4.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=1; total time= 4.4min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=2; total time= 4.4min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=2; total time= 4.5min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=2; total time= 4.5min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=1; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=3, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=2; total time= 4.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=2; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=2; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=2; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=4, estimator__p=2; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=1; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=1; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=7, estimator__p=2; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=1; total time= 4.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=1; total time= 4.1min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=1; total time= 3.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=1; total time= 3.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=1; total time= 3.2min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=2; total time= 3.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=2; total time= 3.3min
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=1; total time=  18.6s
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=2; total time= 3.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=2; total time= 3.3min
# [CV] END estimator__algorithm=ball_tree, estimator__n_neighbors=9, estimator__p=2; total time= 3.3min
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=1; total time=  18.8s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=1; total time=  18.8s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=1; total time=  19.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=2; total time=  17.0s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=2; total time=  16.9s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=1; total time=  19.4s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=2; total time=  17.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=2; total time=  17.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=3, estimator__p=2; total time=  17.4s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=1; total time=  20.9s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=1; total time=  20.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=1; total time=  20.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=1; total time=  20.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=1; total time=  20.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=2; total time=  18.0s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=2; total time=  18.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=2; total time=  17.9s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=2; total time=  18.0s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=4, estimator__p=2; total time=  17.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=1; total time=  22.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=1; total time=  22.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=1; total time=  22.6s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=1; total time=  23.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=2; total time=  20.7s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=1; total time=  24.2s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=2; total time=  21.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=2; total time=  22.2s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=2; total time=  21.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=7, estimator__p=2; total time=  21.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=1; total time=  25.0s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=1; total time=  24.3s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=1; total time=  23.3s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=1; total time=  22.5s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=1; total time=  22.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=2; total time=  18.3s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=2; total time=  18.1s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=2; total time=  18.0s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=2; total time=  17.9s
# [CV] END estimator__algorithm=auto, estimator__n_neighbors=9, estimator__p=2; total time=  17.7s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=1; total time=  17.0s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=1; total time=  16.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=1; total time=  16.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=1; total time=  16.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=2; total time=  14.5s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=1; total time=  16.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=2; total time=  14.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=2; total time=  14.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=2; total time=  14.5s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=3, estimator__p=2; total time=  14.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=1; total time=  17.5s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=1; total time=  17.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=1; total time=  17.2s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=1; total time=  17.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=2; total time=  14.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=2; total time=  14.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=1; total time=  17.1s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=2; total time=  15.0s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=2; total time=  14.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=4, estimator__p=2; total time=  14.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=1; total time=  18.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=1; total time=  18.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=1; total time=  18.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=1; total time=  18.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=2; total time=  15.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=1; total time=  18.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=2; total time=  15.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=2; total time=  15.8s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=2; total time=  15.8s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=7, estimator__p=2; total time=  15.9s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=1; total time=  19.5s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=1; total time=  19.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=1; total time=  19.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=1; total time=  19.4s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=2; total time=  16.6s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=1; total time=  19.0s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=2; total time=  15.1s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=2; total time=  14.7s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=2; total time=  13.3s
# [CV] END estimator__algorithm=kd_tree, estimator__n_neighbors=9, estimator__p=2; total time=  13.1s
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=2; total time= 4.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=2; total time= 4.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=2; total time= 4.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=2; total time= 4.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=2; total time= 4.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=1; total time=10.7min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=1; total time=10.7min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=1; total time=10.7min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=1; total time=10.8min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=3, estimator__p=1; total time=10.7min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=2; total time= 6.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=2; total time= 6.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=2; total time= 6.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=1; total time=13.5min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=2; total time= 7.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=2; total time= 7.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=1; total time=15.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=1; total time=15.8min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=1; total time=15.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=4, estimator__p=1; total time=15.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=2; total time= 6.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=1; total time=16.2min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=2; total time= 6.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=2; total time= 6.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=1; total time=16.1min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=2; total time= 6.9min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=1; total time=16.1min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=2; total time= 7.0min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=1; total time=16.3min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=7, estimator__p=1; total time=16.1min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=2; total time= 7.2min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=2; total time= 7.2min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=2; total time= 7.2min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=1; total time=16.3min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=1; total time=16.3min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=1; total time=16.3min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=2; total time= 5.1min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=2; total time= 5.1min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=1; total time=14.4min
# [CV] END estimator__algorithm=brute, estimator__n_neighbors=9, estimator__p=1; total time=13.2min
#
# KNN
# Best params: {'estimator__algorithm': 'ball_tree', 'estimator__n_neighbors': 9, 'estimator__p': 2}
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      7946
#            1       0.75      0.78      0.76      6806
#            2       0.70      0.76      0.73     10207
#            3       0.81      0.72      0.76      9487
#
#     accuracy                           0.79     34446
#    macro avg       0.80      0.79      0.79     34446
# weighted avg       0.79      0.79      0.79     34446
# train
#
# KNN
# Best params: {'estimator__algorithm': 'ball_tree', 'estimator__n_neighbors': 9, 'estimator__p': 2}
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     31783
#            1       0.78      0.81      0.79     27227
#            2       0.74      0.80      0.77     40828
#            3       0.86      0.75      0.80     37946
#
#     accuracy                           0.82    137784
#    macro avg       0.83      0.82      0.82    137784
# weighted avg       0.82      0.82      0.82    137784
