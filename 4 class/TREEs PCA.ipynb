# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost 
from sklearn.manifold import TSNE
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_auc_score, 
)
from sklearn.decomposition import PCA

plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv('Copia de data_merged.csv')

# %%
df_processed = df.copy()

initial_rows = len(df_processed)
df_processed = df_processed.dropna()

df_processed['duration_ms'] = df_processed['duration_ms']/60000

def categorize_popularity(popularity):
    if popularity == 0:
        return 0 #no popular
    elif popularity<=20:
        return 1 # baja
    elif popularity <=40:
        return 2 # media
    return 3 # alta

df_processed['popularity_multiclass'] = df_processed['popularity'].apply(categorize_popularity)
print("\nVariable multiclase 3 niveles (popularity_multiclass):")
multiclass_counts = df_processed['popularity_multiclass'].value_counts().sort_index()
multiclass_labels = ['no popular','Baja', 'Media', 'Alta']
for i, (count, label) in enumerate(zip(multiclass_counts, multiclass_labels)):
    print(f"   {i} ({label}): {count} ({count/len(df_processed)*100:.1f}%)")
# Out:
# Variable multiclase 3 niveles (popularity_multiclass):
#    0 (no popular): 39729 (23.1%)
#    1 (Baja): 34033 (19.8%)
#    2 (Media): 51035 (29.6%)
#    3 (Alta): 47433 (27.5%)

# %%
df_processed['popularity_multiclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='popularity_multiclass'>

# %%
_X = df_processed.copy()

X = _X.drop(columns=['popularity','popularity_multiclass'])
y_multiclass_3 = df_processed['popularity_multiclass']

# %%
df_processed.groupby('popularity_multiclass')['popularity'].describe()
# Out:
#                          count       mean       std   min   25%   50%   75%  \
# popularity_multiclass
# 0                      39729.0   0.000000  0.000000   0.0   0.0   0.0   0.0
# 1                      34033.0   9.619575  6.125172   1.0   4.0   9.0  15.0
# 2                      51035.0  30.747330  5.652618  21.0  26.0  31.0  36.0
# 3                      47433.0  54.153163  9.966513  41.0  46.0  52.0  61.0
#
#                          max
# popularity_multiclass
# 0                        0.0
# 1                       20.0
# 2                       40.0
# 3                      100.0

# %%
pca = PCA(n_components=0.95)
X_pca=pca.fit_transform(X)

# %%
_X=X_pca
y =y_multiclass_3

# %%
scaler1 = StandardScaler()

X_train_reduce, X_test_reduce, y_train_reduce, y_test_reduce = train_test_split(
    _X, y, 
    test_size=0.2, 
    stratify=y,
    random_state=42
)

# %%
X_train_reduce = scaler1.fit_transform(X_train_reduce)
X_test_scaled = scaler1.transform(X_test_reduce)

# %%
from sklearn.ensemble import ExtraTreesClassifier,HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
models = {
    'RandomForest': RandomForestClassifier(class_weight='balanced'),
    'HistoradientBoosting': HistGradientBoostingClassifier(),
    'XGBoost': xgboost.XGBClassifier(objective='multi:softmax',num_class=4),
    'ExtraTrees': ExtraTreesClassifier(class_weight='balanced'),
    'DecisionTree': DecisionTreeClassifier(class_weight='balanced'),
}
param_grids = {
    
    'RandomForest': {
        'n_estimators': [100, 300, 500],
        'max_depth': [None, 10, 20]
    },
    'XGBoost': {
        'n_estimators': [100, 300, 500],
        'max_depth': [3, 10, 20]
    },
    'ExtraTrees': {
        'n_estimators': [100, 300, 500],
        'max_depth': [None, 10, 20]
    },
    'DecisionTree': {
        'max_depth': [None, 10, 20]
    },
    'HistoradientBoosting':{
        'max_iter':[100,200,300],
        'max_depth':[3,5],

    }
}
results = {}

for name, model in models.items():
    grid = GridSearchCV(model, param_grids[name], cv=5, scoring='f1_macro', n_jobs=-1,verbose=2)
    grid.fit(X_train_reduce, y_train_reduce)
    best = grid.best_estimator_
    y_pred = best.predict(X_test_scaled)
    r = classification_report(y_test_reduce, y_pred)
    print(f"\n{name}")
    print(f"Best params: {grid.best_params_}")
    print(r)
    cm = confusion_matrix(y_test_reduce, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['No Popular', 'bajo','media','alta'],
                yticklabels=['No Popular', 'bajo','media','alta'])
    plt.title(f'{name} - Confusion Matrix')
    plt.ylabel('Valor Real')
    plt.xlabel('Predicción')
    plt.show()
    results[name] = grid.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ...................max_depth=None, n_estimators=100; total time=  51.6s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  51.8s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  51.9s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  51.9s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  51.9s
# [CV] END ...................max_depth=None, n_estimators=300; total time= 2.6min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 2.7min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 2.7min
# [CV] END .....................max_depth=10, n_estimators=100; total time=  28.8s
# [CV] END ...................max_depth=None, n_estimators=300; total time= 2.6min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 2.6min
# [CV] END .....................max_depth=10, n_estimators=100; total time=  29.9s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  29.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  29.3s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  28.9s
# [CV] END ...................max_depth=None, n_estimators=500; total time= 4.5min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 4.5min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 4.5min
# [CV] END .....................max_depth=10, n_estimators=300; total time= 1.5min
# [CV] END .....................max_depth=10, n_estimators=300; total time= 1.5min
# [CV] END .....................max_depth=10, n_estimators=300; total time= 1.5min
# [CV] END .....................max_depth=10, n_estimators=300; total time= 1.5min
# [CV] END .....................max_depth=10, n_estimators=300; total time= 1.5min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 4.4min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 4.4min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  45.4s
# [CV] END .....................max_depth=10, n_estimators=500; total time= 2.5min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  45.3s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  45.0s
# [CV] END .....................max_depth=10, n_estimators=500; total time= 2.4min
# [CV] END .....................max_depth=10, n_estimators=500; total time= 2.5min
# [CV] END .....................max_depth=10, n_estimators=500; total time= 2.4min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  44.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  44.5s
# [CV] END .....................max_depth=10, n_estimators=500; total time= 2.4min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 2.2min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 2.2min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 2.2min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 2.2min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 2.2min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 3.2min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 3.2min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.9min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.6min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.6min
#
# RandomForest
# Best params: {'max_depth': 20, 'n_estimators': 500}
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      7946
#            1       0.70      0.72      0.71      6806
#            2       0.66      0.72      0.69     10207
#            3       0.71      0.62      0.66      9487
#
#     accuracy                           0.73     34446
#    macro avg       0.73      0.73      0.73     34446
# weighted avg       0.73      0.73      0.73     34446
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ..........................max_depth=3, max_iter=100; total time=   6.0s
# [CV] END ..........................max_depth=3, max_iter=100; total time=   6.0s
# [CV] END ..........................max_depth=3, max_iter=100; total time=   6.0s
# [CV] END ..........................max_depth=3, max_iter=100; total time=   6.0s
# [CV] END ..........................max_depth=3, max_iter=100; total time=   6.0s
# [CV] END ..........................max_depth=3, max_iter=200; total time=  11.7s
# [CV] END ..........................max_depth=3, max_iter=200; total time=  11.7s
# [CV] END ..........................max_depth=3, max_iter=200; total time=  11.7s
# [CV] END ..........................max_depth=3, max_iter=200; total time=  11.7s
# [CV] END ..........................max_depth=3, max_iter=200; total time=  11.8s
# [CV] END ..........................max_depth=3, max_iter=300; total time=  17.4s
# [CV] END ..........................max_depth=3, max_iter=300; total time=  17.5s
# [CV] END ..........................max_depth=3, max_iter=300; total time=  17.6s
# [CV] END ..........................max_depth=5, max_iter=100; total time=   8.3s
# [CV] END ..........................max_depth=5, max_iter=100; total time=   8.3s
# [CV] END ..........................max_depth=5, max_iter=100; total time=   8.3s
# [CV] END ..........................max_depth=5, max_iter=100; total time=   8.3s
# [CV] END ..........................max_depth=5, max_iter=100; total time=   8.3s
# [CV] END ..........................max_depth=3, max_iter=300; total time=  17.4s
# [CV] END ..........................max_depth=3, max_iter=300; total time=  17.5s
# [CV] END ..........................max_depth=5, max_iter=200; total time=  16.0s
# [CV] END ..........................max_depth=5, max_iter=200; total time=  15.9s
# [CV] END ..........................max_depth=5, max_iter=200; total time=  16.0s
# [CV] END ..........................max_depth=5, max_iter=200; total time=  16.2s
# [CV] END ..........................max_depth=5, max_iter=200; total time=  14.9s
# [CV] END ..........................max_depth=5, max_iter=300; total time=  20.6s
# [CV] END ..........................max_depth=5, max_iter=300; total time=  19.8s
# [CV] END ..........................max_depth=5, max_iter=300; total time=  19.8s
# [CV] END ..........................max_depth=5, max_iter=300; total time=  17.4s
# [CV] END ..........................max_depth=5, max_iter=300; total time=  17.0s
#
# HistoradientBoosting
# Best params: {'max_depth': 5, 'max_iter': 300}
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76      7946
#            1       0.63      0.58      0.61      6806
#            2       0.60      0.72      0.65     10207
#            3       0.63      0.53      0.57      9487
#
#     accuracy                           0.65     34446
#    macro avg       0.65      0.65      0.65     34446
# weighted avg       0.65      0.65      0.65     34446
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ......................max_depth=3, n_estimators=100; total time=   6.0s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   6.1s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   6.1s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   6.2s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   6.1s
# [CV] END ......................max_depth=3, n_estimators=300; total time=  17.6s
# [CV] END ......................max_depth=3, n_estimators=300; total time=  17.6s
# [CV] END ......................max_depth=3, n_estimators=300; total time=  17.6s
# [CV] END ......................max_depth=3, n_estimators=300; total time=  17.5s
# [CV] END ......................max_depth=3, n_estimators=300; total time=  17.6s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  13.8s
# [CV] END ......................max_depth=3, n_estimators=500; total time=  29.7s
# [CV] END ......................max_depth=3, n_estimators=500; total time=  29.7s
# [CV] END ......................max_depth=3, n_estimators=500; total time=  29.9s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  13.8s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  13.9s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  14.7s
# [CV] END ......................max_depth=3, n_estimators=500; total time=  31.3s
# [CV] END ......................max_depth=3, n_estimators=500; total time=  31.5s
# [CV] END .....................max_depth=10, n_estimators=100; total time=  15.6s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  44.5s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  44.3s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  44.2s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  44.8s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  44.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  39.3s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  39.3s
# [CV] END .....................max_depth=10, n_estimators=500; total time= 1.2min
# [CV] END .....................max_depth=10, n_estimators=500; total time= 1.2min
# [CV] END .....................max_depth=10, n_estimators=500; total time= 1.2min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  38.5s
# [CV] END .....................max_depth=10, n_estimators=500; total time= 1.2min
# [CV] END .....................max_depth=10, n_estimators=500; total time= 1.2min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  39.7s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  40.3s
# [CV] END .....................max_depth=20, n_estimators=300; total time= 1.7min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 1.7min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 1.8min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 1.7min
# [CV] END .....................max_depth=20, n_estimators=300; total time= 1.7min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.3min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.3min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 2.3min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 1.6min
# [CV] END .....................max_depth=20, n_estimators=500; total time= 1.6min
#
# XGBoost
# Best params: {'max_depth': 10, 'n_estimators': 300}
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      7946
#            1       0.69      0.66      0.67      6806
#            2       0.64      0.70      0.67     10207
#            3       0.67      0.61      0.63      9487
#
#     accuracy                           0.70     34446
#    macro avg       0.70      0.70      0.70     34446
# weighted avg       0.70      0.70      0.70     34446
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ...................max_depth=None, n_estimators=100; total time=  28.7s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  28.9s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  28.9s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  29.0s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  29.1s
# [CV] END ...................max_depth=None, n_estimators=300; total time= 1.7min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 1.7min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 1.7min
# [CV] END .....................max_depth=10, n_estimators=100; total time=   6.6s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   5.0s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   4.9s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   5.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   5.2s
# [CV] END ...................max_depth=None, n_estimators=300; total time= 1.8min
# [CV] END ...................max_depth=None, n_estimators=300; total time= 1.8min
# [CV] END .....................max_depth=10, n_estimators=300; total time=  19.0s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  18.2s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  18.5s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  16.7s
# [CV] END .....................max_depth=10, n_estimators=300; total time=  16.7s
# [CV] END .....................max_depth=10, n_estimators=500; total time=  27.8s
# [CV] END .....................max_depth=10, n_estimators=500; total time=  27.6s
# [CV] END .....................max_depth=10, n_estimators=500; total time=  28.8s
# [CV] END ...................max_depth=None, n_estimators=500; total time= 3.0min
# [CV] END .....................max_depth=10, n_estimators=500; total time=  29.5s
# [CV] END ...................max_depth=None, n_estimators=500; total time= 3.0min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 3.0min
# [CV] END .....................max_depth=20, n_estimators=100; total time=  15.3s
# [CV] END .....................max_depth=10, n_estimators=500; total time=  31.5s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  16.2s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  15.5s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  15.3s
# [CV] END .....................max_depth=20, n_estimators=100; total time=  15.4s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  45.0s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  46.1s
# [CV] END ...................max_depth=None, n_estimators=500; total time= 2.9min
# [CV] END ...................max_depth=None, n_estimators=500; total time= 2.8min
# [CV] END .....................max_depth=20, n_estimators=300; total time=  44.6s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  44.4s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  44.6s
# [CV] END .....................max_depth=20, n_estimators=500; total time= 1.0min
# [CV] END .....................max_depth=20, n_estimators=500; total time=  47.1s
# [CV] END .....................max_depth=20, n_estimators=500; total time=  40.9s
# [CV] END .....................max_depth=20, n_estimators=500; total time=  39.0s
# [CV] END .....................max_depth=20, n_estimators=500; total time=  38.6s
#
# ExtraTrees
# Best params: {'max_depth': None, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      7946
#            1       0.67      0.70      0.69      6806
#            2       0.65      0.62      0.64     10207
#            3       0.65      0.66      0.66      9487
#
#     accuracy                           0.71     34446
#    macro avg       0.71      0.71      0.71     34446
# weighted avg       0.71      0.71      0.71     34446
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END .......................................max_depth=10; total time=   0.8s
# [CV] END .......................................max_depth=10; total time=   0.8s
# [CV] END .......................................max_depth=10; total time=   0.8s
# [CV] END .....................................max_depth=None; total time=   1.4s
# [CV] END .....................................max_depth=None; total time=   1.3s
# [CV] END .....................................max_depth=None; total time=   1.3s
# [CV] END .....................................max_depth=None; total time=   1.3s
# [CV] END .....................................max_depth=None; total time=   1.4s
# [CV] END .......................................max_depth=10; total time=   0.7s
# [CV] END .......................................max_depth=10; total time=   0.8s
# [CV] END .......................................max_depth=20; total time=   1.0s
# [CV] END .......................................max_depth=20; total time=   0.9s
# [CV] END .......................................max_depth=20; total time=   0.9s
# [CV] END .......................................max_depth=20; total time=   0.9s
# [CV] END .......................................max_depth=20; total time=   0.9s
#
# DecisionTree
# Best params: {'max_depth': 20}
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      7946
#            1       0.67      0.71      0.69      6806
#            2       0.65      0.66      0.66     10207
#            3       0.66      0.63      0.64      9487
#
#     accuracy                           0.70     34446
#    macro avg       0.71      0.71      0.71     34446
# weighted avg       0.70      0.70      0.70     34446
